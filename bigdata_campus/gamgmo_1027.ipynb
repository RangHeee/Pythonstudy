# %%
import folium

# %%
folium.__version__
# Out:
# '0.14.0'

# %%
map1 = folium.Map(location = [37.478589, 127.118759], zoom_start = 10)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m1 = folium.Circle([37.5691778, 126.8489398], zoom_start = 200, popup = '<b>장애인 체육시설</b> <i>기쁜우리체육센터</i>',
                   color = 'green', radius = 500, fill = True)
m1.add_to(map1)
m2 = folium.Circle([37.5808067, 126.9317169], zoom_start = 200, popup = '<b>장애인 체육시설</b> <i>서대문문화체육회관</i>',
                   color = 'green', radius = 500, fill = True)
m2.add_to(map1)
m3 = folium.Circle([37.5662360, 127.1732613], zoom_start = 200, popup = '<b>장애인 체육시설</b> <i>홀트강동복지관</i>',
                   color = 'green', radius = 500, fill = True)
m3.add_to(map1)
m4 = folium.Circle([37.6014086, 127.0326950], zoom_start = 200, popup = '<b>장애인 체육시설</b> <i>성북장애인가족지원센터</i>',
                   color = 'green', radius = 500, fill = True)
m4.add_to(map1)
m5 = folium.Circle([37.6355613, 127.0747073], zoom_start = 200, popup = '<b>장애인 체육시설</b> <i>하늘꿈아동발달센터</i>',
                   color = 'green', radius = 500, fill = True)
m5.add_to(map1)
m6 = folium.Circle([37.5004279, 127.1354797], zoom_start = 200, popup = '<b>장애인 체육시설</b> <i>서울곰두리체육센터</i>',
                   color = 'green', radius = 500, fill = True)
m6.add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
